# %% [markdown]
# # **Hierarchical Clustering**

# %% [markdown]
# ### Definition: It is unsupervised machine learning. It is also a type of clustering. We make a  top up and bottom up links. We come from top to bottom or bottom to top. W e do not define the number of clusters means K is not mentioned. It shows of dendograms. It gives best vizulaization to divide the clusters through dendograms.
#
# ## Two methods are as follows
#
# ### 1- Agglomerative (Bottom up):
#
#      ## *All data points are shown cluster and merging them by bottom up approach*
#
# ### 2- Divisive (Top down):
#
#      ## *Starting with bigger cluster and dividing more and more in detail and cluster are increased through this. It just a way to increase the detail of clusters*

# %% [markdown]
# ## **Coding**

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as sch
from sklearn.datasets import make_blobs

## Generate a random dataset with 100 samples and 3 feartures

X,y = make_blobs(n_samples=100 , centers=3, n_features=3, random_state=42)

## Performing Hierarchical Clustering with the Agglomerative clustering Algorithm 

clustering = AgglomerativeClustering(n_clusters=3, linkage='ward')
clustering.fit(X)

## Plotting the dendrogram 

plt.figure(figsize=(10, 7))
plt.title("Dendrogram")
dendrogram = sch.dendrogram(sch.linkage(X, method='ward'))
plt.show()
