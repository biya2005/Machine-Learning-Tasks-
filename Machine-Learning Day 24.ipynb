# %% [markdown]
# # **DBSCAN in Un-Supervised Learning**

# %% [markdown]
# ### Details of DBSCAN
# #### It is unsupervised machine leaning algorithm in which clustering is done.
#
# ### DBSCAN
# ## Density: Something in some space. It will some data points and area.
# ## Based
# ## Spatial : If we measure the space wise density is called spatial
# ## Clustering
# ## Application
# ## Noise : Some points that are left and not come in the points of clusters. It is called noise or can be outliers.

# %% [markdown]
# # **Coding Time**

# %%
from sklearn.datasets import load_iris
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt 


## Load the Iris dataset 
iris = load_iris()
X = iris.data

# Standardize the data 
X_scaled = StandardScaler().fit_transform(X)

## Creatuing the DBSCAN object 
dbscan = DBSCAN(eps=0.3, min_samples=5)

## Fitting the model 
dbscan.fit(X_scaled)

## Plotting the dat points as a coloure coded clusters 
plt.scatter(X[:, 0], X[:, 1], c=dbscan.labels_)
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[2])
plt.title("DBSCAN Clustering on Iris Dataset")
plt.show()

# %% [markdown]
# # **Optics**

# %% [markdown]
# ### Optics is the extension of DBSACN. It orders the points to identify the clustering structures. It stands for ( Ordering Points to Identify The Clustering Points). It also requires the e and min points hyperparameters same as DBSCAN.
